# %%
# Just for the notebooks, the cwd needs to be set to the root of the project
import os
from pathlib import Path
home = Path.home()

cwd = os.getcwd()
if not 'initial_cwd' in locals():
	initial_cwd = cwd

# check if any of the parent directories is 'notebooks'
relative_path = Path(cwd).relative_to(home)
if 'notebooks' in relative_path.parts:
	# if so, change the current working directory to the root of the project
	while relative_path.parts and not 'notebooks' in os.listdir(cwd):
		cwd = os.path.dirname(cwd)
		relative_path = Path(cwd).relative_to(home)
	if 'notebooks' in os.listdir(cwd):
		os.chdir(cwd)

print(f"Current working directory: {os.getcwd()}")
print(f"Initial working directory: {initial_cwd}")
# Out:
# Current working directory: /home/cyphix/repos/pixel-ota
# Initial working directory: /home/cyphix/repos/pixel-ota/notebooks

# %%
# %pip install -r requirements.txt --quiet
from dotenv import load_dotenv
load_dotenv()
# Out:
# Note: you may need to restart the kernel to use updated packages.
# False

# %% [markdown]
# # Setup logging

# %%
import logging
from LoggingColor import ColorHandler
import sys
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s.%(msecs)03d %(name)-16s [%(levelname)-1s]: %(message)s',
    handlers=[
        logging.FileHandler(f'log.log',mode='w'),
        #logging.StreamHandler(sys.stdout),
        ColorHandler(sys.stdout)
    ],
    datefmt='%H:%M:%S'
)

logger = logging.getLogger(__name__)
logger.debug("Debug log test")
logger.info("Info log test")
logger.warning("Warning log test")
logger.error("Error log test")
logger.critical("Critical log test")
# Out:
# 18:57:18.230 __main__         [D]: Debug log test
# 18:57:18.230 __main__         [I]: Info log test
# 18:57:18.230 __main__         [W]: Warning log test
# 18:57:18.230 __main__         [E]: Error log test
# 18:57:18.230 __main__         [C]: Critical log test

# %% [markdown]
# # Fetch ota links

# %%
from dataclasses import dataclass, field

@dataclass
class OTAInfo:
    android_version: str
    buildID: str
    build_branch: str
    build_date: str
    build_number: str
    build_variant: str | None
    carrier: str | None
    device: str
    url: str
    checksum: str

    def download(self, download_dir: str, filename: str = None, overwrite: bool = False) -> str:
        import requests
        import os
        from tqdm.auto import tqdm

        if filename is None:
            filename = f"{self.device}-ota-{self.buildID}.zip"

        os.makedirs(download_dir, exist_ok=True)
        out_path = os.path.join(download_dir, filename)

        if not overwrite and os.path.exists(out_path):
            logger.warning(f"File {out_path} already exists, skipping download.")
        else:
            logger.info(f"Downloading OTA {self.android_version}, {self.buildID} for {self.device} to {out_path}")
            temp_path = out_path + ".part"
            with requests.get(self.url, stream=True) as r:
                total_size = int(r.headers.get('content-length', 0))
                with tqdm(total=total_size, unit='B', unit_scale=True, desc=filename) as pbar:
                    with open(temp_path, 'wb') as f:
                        for chunk in r.iter_content(chunk_size=8192):
                            f.write(chunk)
                            pbar.update(len(chunk))
                assert total_size == os.path.getsize(temp_path), f"Downloaded file size {os.path.getsize(temp_path)} does not match expected size {total_size}"

            os.rename(temp_path, out_path)
        
        # verify checksum
        import hashlib
        sha256 = hashlib.sha256()
        with open(out_path, 'rb') as f:
            with tqdm(total=os.path.getsize(out_path), unit='B', unit_scale=True, desc="Verifying checksum") as pbar:
                for chunk in iter(lambda: f.read(8192), b''):
                    sha256.update(chunk)
                    pbar.update(len(chunk))
        calculated_checksum = sha256.hexdigest()
        if calculated_checksum != self.checksum:
            logger.error(f"Checksum mismatch for {out_path}: expected {self.checksum}, got {calculated_checksum}")
            os.remove(out_path)
            raise ValueError(f"Checksum mismatch for {out_path}: expected {self.checksum}, got {calculated_checksum}")
        else:
            logger.info(f"Checksum verified for {out_path}")
        return out_path

def fetchAllOTA() -> list[OTAInfo]:
    import requests
    import re

    with requests.Session() as s:
        cookies = {
            "devsite_wall_acks": "nexus-ota-tos",
        }

        s.cookies.update(cookies)
        res = s.get("https://developers.google.com/android/ota")

    assert res.status_code == 200, f"Failed to fetch OTA page: {res.status_code}"

    from bs4 import BeautifulSoup
    soup = BeautifulSoup(res.text, 'html.parser')

    # find all table rows
    rows = soup.find_all('tr')
    logger.info(f"Found {len(rows)} rows in the OTA table")

    available_otas = []
    for row in rows:
        # There should be 3 columns: Version, Download, and checksum
        cols = row.find_all('td')

        if len(cols) != 3:
            logger.warning(f"Skipping row with {len(cols)} columns")
            continue
        version_col, download_col, checksum_col = cols

        # extract the version data
        version_text = version_col.get_text(strip=True)
        match = re.match(r'^(\d+\.\d+\.\d+)\s+\(([^,]+),\s+([^,]+)(?:,\s+([^)]+))?\)$', version_text)
        if not match:
            logger.warning(f"Skipping row with unrecognized version format: {version_text}")
            continue
        android_ver, build_id, security_level, carrier  = match.groups()

        split_build_id = build_id.split('.')
        try:
            build_branch_code, build_date, build_number = split_build_id[:3]
        except Exception as e:
            logger.error(f"Error parsing build ID '{build_id}' (most likely due to old version format): {e}")
            continue
        build_variant = split_build_id[3] if len(split_build_id) > 3 else None

        # get the device name from the row using the build_id
        row_id = row.get('id')
        # the format is <device>-<build_id>
        device = row_id.lower().replace(f"{build_id.lower()}", "")

        logger.info(f"Parsed version: Android {android_ver}, Build {build_id}, Security {security_level}, Carrier {carrier}")
        logger.debug(f"Device: {device}")
        logger.debug(f"Build details: Branch {build_branch_code}, Date {build_date}, Number {build_number}, Variant {build_variant}")


        # extract the download link
        a_tag = download_col.find('a', href=True)
        if not a_tag:
            logger.warning("Skipping row with no download link")
            continue
        dl_link = a_tag['href']
        logger.info(f"Found download link: {dl_link}")

        checksum_text = checksum_col.get_text(strip=True)
        logger.info(f"Checksum: {checksum_text}")
        ota_info = OTAInfo(
            android_version=android_ver,
            buildID=build_id,
            build_branch=build_branch_code,
            build_date=build_date,
            build_number=build_number,
            build_variant=build_variant,
            carrier=carrier,
            device=device,
            url=dl_link,
            checksum=checksum_text
        )
        available_otas.append(ota_info)

    return available_otas

otas = fetchAllOTA()
logger.info(f"Fetched {len(otas)} OTA entries")
# Out:
# 19:13:17.664 urllib3.connectionpool [D]: Starting new HTTPS connection (1): developers.google.com:443
# 19:13:18.612 urllib3.connectionpool [D]: https://developers.google.com:443 "GET /android/ota HTTP/1.1" 200 None
# 19:13:19.151 __main__         [I]: Found 1696 rows in the OTA table
# 19:13:19.151 __main__         [I]: Parsed version: Android 16.0.0, Build BD1A.250702.001, Security Aug 2025, Carrier None
# 19:13:19.151 __main__         [D]: Device: blazer
# 19:13:19.151 __main__         [D]: Build details: Branch BD1A, Date 250702, Number 001, Variant None
# 19:13:19.151 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/blazer-ota-bd1a.250702.001-23331fee.zip
# 19:13:19.151 __main__         [I]: Checksum: 23331feef312884bac74cc5d058f4c30d017443d2e984168250c550ac3883151
# 19:13:19.151 __main__         [I]: Parsed version: Android 16.0.0, Build BD1A.250702.001.A3, Security Aug 2025, Carrier Verizon
# 19:13:19.151 __main__         [D]: Device: blazer
# 19:13:19.151 __main__         [D]: Build details: Branch BD1A, Date 250702, Number 001, Variant A3
# 19:13:19.151 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/blazer-ota-bd1a.250702.001.a3-9bff160f.zip
# 19:13:19.151 __main__         [I]: Checksum: 9bff160fc90e80e8ed9b4c05256f6b688b9cc32a1f9abc7fd4c22f5ab59f726a
# 19:13:19.151 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001, Security Aug 2025, Carrier None
# 19:13:19.151 __main__         [D]: Device: blazer
# 19:13:19.151 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant None
# 19:13:19.151 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/blazer-ota-bd3a.250721.001-ca3da1c9.zip
# 19:13:19.151 __main__         [I]: Checksum: ca3da1c9894bd253e8977252a7074e30639c30625fa04fe25ce39dc68161624d
# 19:13:19.151 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.A1, Security Aug 2025, Carrier NA GStore
# 19:13:19.151 __main__         [D]: Device: blazer
# 19:13:19.151 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant A1
# 19:13:19.151 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/blazer-ota-bd3a.250721.001.a1-2a139ae1.zip
# 19:13:19.151 __main__         [I]: Checksum: 2a139ae146d1ff25ae3dd0948857e49b77e024f6d7d916c7b1d4619e24e637e7
# 19:13:19.151 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.B7, Security Sep 2025, Carrier None
# 19:13:19.151 __main__         [D]: Device: blazer
# 19:13:19.151 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant B7
# 19:13:19.151 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/blazer-ota-bd3a.250721.001.b7-a3516634.zip
# 19:13:19.151 __main__         [I]: Checksum: a3516634ee37da49f79c6a768d3dba5b31a6f5679099838ab371c303ae6f2eac
# 19:13:19.151 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.E1, Security Sep 2025, Carrier None
# 19:13:19.151 __main__         [D]: Device: blazer
# 19:13:19.152 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant E1
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/blazer-ota-bd3a.250721.001.e1-b35713f5.zip
# 19:13:19.152 __main__         [I]: Checksum: b35713f5118a58a9479fb81548fe3776cfadfe9d9177fc55c7bee4412d435bf7
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD1A.250702.001, Security Aug 2025, Carrier None
# 19:13:19.152 __main__         [D]: Device: frankel
# 19:13:19.152 __main__         [D]: Build details: Branch BD1A, Date 250702, Number 001, Variant None
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/frankel-ota-bd1a.250702.001-82bd95c6.zip
# 19:13:19.152 __main__         [I]: Checksum: 82bd95c69c03e13ccc761be2d9a7d65138f85832cfc946de7374df58d76e98c5
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD1A.250702.001.A3, Security Aug 2025, Carrier Verizon
# 19:13:19.152 __main__         [D]: Device: frankel
# 19:13:19.152 __main__         [D]: Build details: Branch BD1A, Date 250702, Number 001, Variant A3
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/frankel-ota-bd1a.250702.001.a3-3c8a6dc8.zip
# 19:13:19.152 __main__         [I]: Checksum: 3c8a6dc8bf8a8a31aab3a25343a4752797c368e4bd04a079ef09f2bb1e2e9755
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001, Security Aug 2025, Carrier None
# 19:13:19.152 __main__         [D]: Device: frankel
# 19:13:19.152 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant None
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/frankel-ota-bd3a.250721.001-0b9b663c.zip
# 19:13:19.152 __main__         [I]: Checksum: 0b9b663c04d04a5b1b52332a4af94c1c73eae1ce32447a1ba7651bf9d6e83b66
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.A1, Security Aug 2025, Carrier NA GStore
# 19:13:19.152 __main__         [D]: Device: frankel
# 19:13:19.152 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant A1
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/frankel-ota-bd3a.250721.001.a1-b5a1d9aa.zip
# 19:13:19.152 __main__         [I]: Checksum: b5a1d9aa0a69a501f1397758ddd36728704489b04e32a74ee073dee9033e9b2d
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.B7, Security Sep 2025, Carrier None
# 19:13:19.152 __main__         [D]: Device: frankel
# 19:13:19.152 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant B7
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/frankel-ota-bd3a.250721.001.b7-e8428d30.zip
# 19:13:19.152 __main__         [I]: Checksum: e8428d301d8c41bec254cedaae9a7c4f12c45c53fce689e5b9bf8a9d0d5d4fb2
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.E1, Security Sep 2025, Carrier None
# 19:13:19.152 __main__         [D]: Device: frankel
# 19:13:19.152 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant E1
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/frankel-ota-bd3a.250721.001.e1-599a21e8.zip
# 19:13:19.152 __main__         [I]: Checksum: 599a21e8f34fb08c5b95afb3b44f267dd36eeebbec525423e400e8c2daf411de
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD1A.250702.001, Security Aug 2025, Carrier None
# 19:13:19.152 __main__         [D]: Device: mustang
# 19:13:19.152 __main__         [D]: Build details: Branch BD1A, Date 250702, Number 001, Variant None
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/mustang-ota-bd1a.250702.001-08db3f85.zip
# 19:13:19.152 __main__         [I]: Checksum: 08db3f854647f344ff24eb90c22016b5f1a0e3dcaa47a6d1afb7818d0396de89
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD1A.250702.001.A3, Security Aug 2025, Carrier Verizon
# 19:13:19.152 __main__         [D]: Device: mustang
# 19:13:19.152 __main__         [D]: Build details: Branch BD1A, Date 250702, Number 001, Variant A3
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/mustang-ota-bd1a.250702.001.a3-db25e3b4.zip
# 19:13:19.152 __main__         [I]: Checksum: db25e3b4b9abd8500379f4d0d3fc546b9299a37c8f6473ed3d7d1de87548a1b9
# 19:13:19.152 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001, Security Aug 2025, Carrier None
# 19:13:19.152 __main__         [D]: Device: mustang
# 19:13:19.152 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant None
# 19:13:19.152 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/mustang-ota-bd3a.250721.001-98d59e63.zip
# 19:13:19.152 __main__         [I]: Checksum: 98d59e63c9a2c5802706600507cb8e2b063f0fbe4406f52ea90a1345b65bcfcd
# 19:13:19.153 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.A1, Security Aug 2025, Carrier NA GStore
# 19:13:19.153 __main__         [D]: Device: mustang
# 19:13:19.153 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant A1
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/mustang-ota-bd3a.250721.001.a1-b31f1038.zip
# 19:13:19.153 __main__         [I]: Checksum: b31f1038cbec321881399c48c94c6022bc3800923d1137bce1ae3bdcd9633be1
# 19:13:19.153 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.B7, Security Sep 2025, Carrier None
# 19:13:19.153 __main__         [D]: Device: mustang
# 19:13:19.153 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant B7
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/mustang-ota-bd3a.250721.001.b7-7727eceb.zip
# 19:13:19.153 __main__         [I]: Checksum: 7727eceb72f6266a3cf26f455ff1356f3fa7ac6065f49cc6441c92cd5547fb39
# 19:13:19.153 __main__         [I]: Parsed version: Android 16.0.0, Build BD3A.250721.001.E1, Security Sep 2025, Carrier None
# 19:13:19.153 __main__         [D]: Device: mustang
# 19:13:19.153 __main__         [D]: Build details: Branch BD3A, Date 250721, Number 001, Variant E1
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/mustang-ota-bd3a.250721.001.e1-e9e7cd5f.zip
# 19:13:19.153 __main__         [I]: Checksum: e9e7cd5f36f2c7520062d8d541a73c4df58eb4a820ab6137fea93ff61bbf17c6
# 19:13:19.153 __main__         [I]: Parsed version: Android 15.0.0, Build BD4A.240925.111, Security Apr 2025, Carrier None
# 19:13:19.153 __main__         [D]: Device: tegu
# 19:13:19.153 __main__         [D]: Build details: Branch BD4A, Date 240925, Number 111, Variant None
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/tegu-ota-bd4a.240925.111-2e1b0f30.zip
# 19:13:19.153 __main__         [I]: Checksum: 2e1b0f30cfc79bc1125aed9cf4eacc84e38a2a288e511e0e5129ae20a335f2fe
# 19:13:19.153 __main__         [I]: Parsed version: Android 15.0.0, Build BD4A.250405.003, Security Apr 2025, Carrier None
# 19:13:19.153 __main__         [D]: Device: tegu
# 19:13:19.153 __main__         [D]: Build details: Branch BD4A, Date 250405, Number 003, Variant None
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/tegu-ota-bd4a.250405.003-9387d8f0.zip
# 19:13:19.153 __main__         [I]: Checksum: 9387d8f01bd877da9a78f2890c6e58b4014e1a3c12105b73590a80e00aba649e
# 19:13:19.153 __main__         [I]: Parsed version: Android 15.0.0, Build BD4A.250505.003, Security May 2025, Carrier None
# 19:13:19.153 __main__         [D]: Device: tegu
# 19:13:19.153 __main__         [D]: Build details: Branch BD4A, Date 250505, Number 003, Variant None
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/tegu-ota-bd4a.250505.003-06eb56e8.zip
# 19:13:19.153 __main__         [I]: Checksum: 06eb56e8bbaf4c593e730b74285519a82bcc5727ea309d1815c944e5f259d18d
# 19:13:19.153 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250605.031.A2, Security Jun 2025, Carrier None
# 19:13:19.153 __main__         [D]: Device: tegu
# 19:13:19.153 __main__         [D]: Build details: Branch BP2A, Date 250605, Number 031, Variant A2
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/tegu-ota-bp2a.250605.031.a2-ec03acfb.zip
# 19:13:19.153 __main__         [I]: Checksum: ec03acfb955eaa7ee4fea409a4a7a28b01c93647f60e34bc75a28ecf196319b4
# 19:13:19.153 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250705.008, Security Jul 2025, Carrier None
# 19:13:19.153 __main__         [D]: Device: tegu
# 19:13:19.153 __main__         [D]: Build details: Branch BP2A, Date 250705, Number 008, Variant None
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/tegu-ota-bp2a.250705.008-84cbc47c.zip
# 19:13:19.153 __main__         [I]: Checksum: 84cbc47cd3d996614a478d85e7650e62ac821a8b618cb0b64b2afc0ce61a29a8
# 19:13:19.153 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250805.005, Security Aug 2025, Carrier None
# 19:13:19.153 __main__         [D]: Device: tegu
# 19:13:19.153 __main__         [D]: Build details: Branch BP2A, Date 250805, Number 005, Variant None
# 19:13:19.153 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/tegu-ota-bp2a.250805.005-567602fb.zip
# 19:13:19.153 __main__         [I]: Checksum: 567602fb5e266f954c36ffb36889951dd7044371c90e97d3f75c3227eebca722
# 19:13:19.154 __main__         [I]: Parsed version: Android 16.0.0, Build BP3A.250905.014, Security Sep 2025, Carrier None
# 19:13:19.154 __main__         [D]: Device: tegu
# 19:13:19.154 __main__         [D]: Build details: Branch BP3A, Date 250905, Number 014, Variant None
# 19:13:19.154 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/tegu-ota-bp3a.250905.014-dd1c4e4e.zip
# 19:13:19.154 __main__         [I]: Checksum: dd1c4e4e118b911072d7d7fb91b534f2b38f4894029b8d4ec657d08f23b8176e
# 19:13:19.154 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.030, Security Aug 2024, Carrier None
# 19:13:19.154 __main__         [D]: Device: comet
# 19:13:19.154 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 030, Variant None
# 19:13:19.154 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ad1a.240530.030-98066022.zip
# 19:13:19.154 __main__         [I]: Checksum: 98066022ebf9482a956b7135f831b7bf1c66f43667193fcb1ddd2adf681f1383
# 19:13:19.154 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.030.A1, Security Aug 2024, Carrier India only
# 19:13:19.154 __main__         [D]: Device: comet
# 19:13:19.154 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 030, Variant A1
# 19:13:19.154 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ad1a.240530.030.a1-1d0d3c25.zip
# 19:13:19.154 __main__         [I]: Checksum: 1d0d3c2590130b636f3ab7a015b84eb1db7d4eb82b4b0266f5097ae1efa3bc3c
# 19:13:19.154 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.047, Security Aug 2024, Carrier None
# 19:13:19.154 __main__         [D]: Device: comet
# 19:13:19.154 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 047, Variant None
# 19:13:19.154 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ad1a.240530.047-a82cf266.zip
# 19:13:19.154 __main__         [I]: Checksum: a82cf266be89a19507b885b50965934ea01d03ec5465ad127b5ee1d4fc1cd61b
# 19:13:19.154 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240905.004, Security Sep 2024, Carrier None
# 19:13:19.154 __main__         [D]: Device: comet
# 19:13:19.154 __main__         [D]: Build details: Branch AD1A, Date 240905, Number 004, Variant None
# 19:13:19.154 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ad1a.240905.004-ba016cd3.zip
# 19:13:19.154 __main__         [I]: Checksum: ba016cd3026a91fc1189f6f249e7f414058a4067e544fb25b1f534d61bce92ec
# 19:13:19.154 __main__         [I]: Parsed version: Android 15.0.0, Build AP3A.241005.015, Security Oct 2024, Carrier None
# 19:13:19.154 __main__         [D]: Device: comet
# 19:13:19.154 __main__         [D]: Build details: Branch AP3A, Date 241005, Number 015, Variant None
# 19:13:19.154 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap3a.241005.015-5350adac.zip
# 19:13:19.154 __main__         [I]: Checksum: 5350adacb10bd370b67f7120cff96975c18a14889b97a855cdd89cb53bff00bc
# 19:13:19.154 __main__         [I]: Parsed version: Android 15.0.0, Build AP3A.241005.015.A2, Security Oct 2024, Carrier Google Fi
# 19:13:19.154 __main__         [D]: Device: comet
# 19:13:19.154 __main__         [D]: Build details: Branch AP3A, Date 241005, Number 015, Variant A2
# 19:13:19.154 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap3a.241005.015.a2-65129544.zip
# 19:13:19.154 __main__         [I]: Checksum: 65129544bc91ba970368d20bdb04fdaf524c0961b674eb27cb0c5de58d546c3a
# 19:13:19.154 __main__         [I]: Parsed version: Android 15.0.0, Build AP3A.241105.008, Security Nov 2024, Carrier None
# 19:13:19.154 __main__         [D]: Device: comet
# 19:13:19.154 __main__         [D]: Build details: Branch AP3A, Date 241105, Number 008, Variant None
# 19:13:19.154 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap3a.241105.008-ebe2f388.zip
# 19:13:19.154 __main__         [I]: Checksum: ebe2f38837b4f8a32dc04f5d3ac53bc9b1ff722fa7cb000237204deadd70179a
# 19:13:19.154 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.241205.013, Security Dec 2024, Carrier None
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.155 __main__         [D]: Build details: Branch AP4A, Date 241205, Number 013, Variant None
# 19:13:19.155 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.241205.013-616bfa66.zip
# 19:13:19.155 __main__         [I]: Checksum: 616bfa66d15b5dfd5c76e00d2a8c78a09ffef320eff56d31bcca51d4e8a003b0
# 19:13:19.155 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.241205.013.B1, Security Dec 2024, Carrier Telstra
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.155 __main__         [D]: Build details: Branch AP4A, Date 241205, Number 013, Variant B1
# 19:13:19.155 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.241205.013.b1-61c6e933.zip
# 19:13:19.155 __main__         [I]: Checksum: 61c6e9336cda13f02170357044f7ea6cab406924abd030d30fe03a90dbfcb408
# 19:13:19.155 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.241205.013.C1, Security Dec 2024, Carrier T-Mobile
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.155 __main__         [D]: Build details: Branch AP4A, Date 241205, Number 013, Variant C1
# 19:13:19.155 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.241205.013.c1-778a50ed.zip
# 19:13:19.155 __main__         [I]: Checksum: 778a50ed590ba9647f635ad8b07d640538274c13d9e98801c8356d7c42f62b73
# 19:13:19.155 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250105.002, Security Jan 2025, Carrier None
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.155 __main__         [D]: Build details: Branch AP4A, Date 250105, Number 002, Variant None
# 19:13:19.155 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.250105.002-9273a642.zip
# 19:13:19.155 __main__         [I]: Checksum: 9273a6429bcee2d0d94fb5bb30bdde30767baa1388e69a2ffda94833339b2264
# 19:13:19.155 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250105.002.B1, Security Jan 2025, Carrier Telstra
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.155 __main__         [D]: Build details: Branch AP4A, Date 250105, Number 002, Variant B1
# 19:13:19.155 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.250105.002.b1-56cce3f6.zip
# 19:13:19.155 __main__         [I]: Checksum: 56cce3f6f53bfd56a839df5924ece7ae36f34aafa6fd841c280340cb2adc58fa
# 19:13:19.155 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250105.002.C1, Security Jan 2025, Carrier T-Mobile
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.155 __main__         [D]: Build details: Branch AP4A, Date 250105, Number 002, Variant C1
# 19:13:19.155 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.250105.002.c1-e9f6472e.zip
# 19:13:19.155 __main__         [I]: Checksum: e9f6472e71307b2a57ff1ca182d30cbacd29ef221d737661548ee10c30830a81
# 19:13:19.155 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250205.002, Security Feb 2025, Carrier None
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.155 __main__         [D]: Build details: Branch AP4A, Date 250205, Number 002, Variant None
# 19:13:19.155 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.250205.002-5b998617.zip
# 19:13:19.155 __main__         [I]: Checksum: 5b998617ac3dc94ed3951b4ff8bb0cbf5e12e9381e559abc2f185d1588db499d
# 19:13:19.155 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250205.002.B2, Security Feb 2025, Carrier Telstra
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.155 __main__         [D]: Build details: Branch AP4A, Date 250205, Number 002, Variant B2
# 19:13:19.155 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.250205.002.b2-a5934141.zip
# 19:13:19.155 __main__         [I]: Checksum: a59341419928828eba5f75f8c2aa1036deac04731ce4d46fe250ab5dafe679a8
# 19:13:19.155 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250205.002.C1, Security Feb 2025, Carrier T-Mobile
# 19:13:19.155 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch AP4A, Date 250205, Number 002, Variant C1
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-ap4a.250205.002.c1-dc4c46af.zip
# 19:13:19.156 __main__         [I]: Checksum: dc4c46afa10392e7e68600aacae7005f90933e91da535d819724d7327092474b
# 19:13:19.156 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250305.020, Security Mar 2025, Carrier None
# 19:13:19.156 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch BP1A, Date 250305, Number 020, Variant None
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250305.020-04e1162a.zip
# 19:13:19.156 __main__         [I]: Checksum: 04e1162afd6c7ae41b5e09bb0697b78bf28858766f6d19ad17cfc9ffab9dafaa
# 19:13:19.156 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250305.020.A2, Security Mar 2025, Carrier EMEA + TW
# 19:13:19.156 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch BP1A, Date 250305, Number 020, Variant A2
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250305.020.a2-f0ed7a81.zip
# 19:13:19.156 __main__         [I]: Checksum: f0ed7a8167f52c64d29cd52beda7341d2ca68bc7be491a9270184110c6007d6f
# 19:13:19.156 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250405.007, Security Apr 2025, Carrier None
# 19:13:19.156 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch BP1A, Date 250405, Number 007, Variant None
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250405.007-3b5a62aa.zip
# 19:13:19.156 __main__         [I]: Checksum: 3b5a62aab3c6d61f455025b40f166e8146339061b54bacc51cdc277a923cfc0a
# 19:13:19.156 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250405.007.A1, Security Apr 2025, Carrier TW, EMEA
# 19:13:19.156 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch BP1A, Date 250405, Number 007, Variant A1
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250405.007.a1-f490c392.zip
# 19:13:19.156 __main__         [I]: Checksum: f490c3923f1d5ec59dda166c105befbea5cb7b6b5b5290d5a5bda50a3897feaf
# 19:13:19.156 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250405.007.C1, Security Apr 2025, Carrier DTAG
# 19:13:19.156 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch BP1A, Date 250405, Number 007, Variant C1
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250405.007.c1-f19674e7.zip
# 19:13:19.156 __main__         [I]: Checksum: f19674e7f2495c08207bc2b3805d0e2cc7e4a9bcbc80ffb31c619bb98acacfe4
# 19:13:19.156 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250405.007.D1, Security Apr 2025, Carrier Verizon
# 19:13:19.156 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch BP1A, Date 250405, Number 007, Variant D1
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250405.007.d1-a7cffabb.zip
# 19:13:19.156 __main__         [I]: Checksum: a7cffabbeb2aca24fd5728a3d55e8cd30e17e40b0ac20b19cff487b798bc7b37
# 19:13:19.156 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250505.005, Security May 2025, Carrier None
# 19:13:19.156 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch BP1A, Date 250505, Number 005, Variant None
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250505.005-d344e885.zip
# 19:13:19.156 __main__         [I]: Checksum: d344e8857143f34c9d16429f9de945a3db91ce01b2534654ad4c220fe4ed2630
# 19:13:19.156 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250505.005.A1, Security May 2025, Carrier TW, EMEA
# 19:13:19.156 __main__         [D]: Device: comet
# 19:13:19.156 __main__         [D]: Build details: Branch BP1A, Date 250505, Number 005, Variant A1
# 19:13:19.156 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250505.005.a1-5110b65d.zip
# 19:13:19.157 __main__         [I]: Checksum: 5110b65dfab075a89c6728efb3c736182cc932e0b968535a88ad71c71167ca44
# 19:13:19.157 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250505.005.C1, Security May 2025, Carrier DTAG
# 19:13:19.157 __main__         [D]: Device: comet
# 19:13:19.157 __main__         [D]: Build details: Branch BP1A, Date 250505, Number 005, Variant C1
# 19:13:19.157 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250505.005.c1-53a0d07f.zip
# 19:13:19.157 __main__         [I]: Checksum: 53a0d07f7fddab55d45132306774a6b1a3282882b02ccfa2617003235e5830a8
# 19:13:19.157 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250505.005.D1, Security May 2025, Carrier Verizon
# 19:13:19.157 __main__         [D]: Device: comet
# 19:13:19.157 __main__         [D]: Build details: Branch BP1A, Date 250505, Number 005, Variant D1
# 19:13:19.157 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp1a.250505.005.d1-da324037.zip
# 19:13:19.157 __main__         [I]: Checksum: da324037c643b2048df1b26e222f56101f4404e33fb1d77515de26fd8a7df88f
# 19:13:19.157 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250605.031.A3, Security Jun 2025, Carrier None
# 19:13:19.157 __main__         [D]: Device: comet
# 19:13:19.157 __main__         [D]: Build details: Branch BP2A, Date 250605, Number 031, Variant A3
# 19:13:19.157 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp2a.250605.031.a3-b6c67e0a.zip
# 19:13:19.157 __main__         [I]: Checksum: b6c67e0a96df3ef2bf75ac8eba49cc50c5aae500f84583221881a665b429a0ec
# 19:13:19.157 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250705.008, Security Jul 2025, Carrier None
# 19:13:19.157 __main__         [D]: Device: comet
# 19:13:19.157 __main__         [D]: Build details: Branch BP2A, Date 250705, Number 008, Variant None
# 19:13:19.157 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp2a.250705.008-2e87ff3b.zip
# 19:13:19.157 __main__         [I]: Checksum: 2e87ff3b94e23785aed71f0135b0aaa616408d5a7447fc1a8a156cfbca66dbbf
# 19:13:19.157 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250805.005, Security Aug 2025, Carrier None
# 19:13:19.157 __main__         [D]: Device: comet
# 19:13:19.157 __main__         [D]: Build details: Branch BP2A, Date 250805, Number 005, Variant None
# 19:13:19.157 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp2a.250805.005-d2303753.zip
# 19:13:19.157 __main__         [I]: Checksum: d230375337f1eed1435781ffce4272877eb45632061431c1c3f96094e189c1d5
# 19:13:19.157 __main__         [I]: Parsed version: Android 16.0.0, Build BP3A.250905.014, Security Sep 2025, Carrier None
# 19:13:19.157 __main__         [D]: Device: comet
# 19:13:19.157 __main__         [D]: Build details: Branch BP3A, Date 250905, Number 014, Variant None
# 19:13:19.157 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/comet-ota-bp3a.250905.014-dfd2757f.zip
# 19:13:19.157 __main__         [I]: Checksum: dfd2757f72fb061c18123025b07868ebe475c3fd1fc6afb694222ca8fe638872
# 19:13:19.157 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.030, Security Aug 2024, Carrier None
# 19:13:19.157 __main__         [D]: Device: caiman
# 19:13:19.157 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 030, Variant None
# 19:13:19.157 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ad1a.240530.030-0fc923fd.zip
# 19:13:19.157 __main__         [I]: Checksum: 0fc923fd7946a73296ab7d1f3740667f6c53dad22b8cb84332badf905aeb4ea4
# 19:13:19.157 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.030.A1, Security Aug 2024, Carrier India only
# 19:13:19.157 __main__         [D]: Device: caiman
# 19:13:19.157 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 030, Variant A1
# 19:13:19.157 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ad1a.240530.030.a1-9d217d6c.zip
# 19:13:19.158 __main__         [I]: Checksum: 9d217d6c9f563d061900b17a2f41459049990030efca58762952067b30693b69
# 19:13:19.158 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.030.A2, Security Aug 2024, Carrier VZW/US Emerging carriers + gStore
# 19:13:19.158 __main__         [D]: Device: caiman
# 19:13:19.158 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 030, Variant A2
# 19:13:19.158 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ad1a.240530.030.a2-33df5025.zip
# 19:13:19.158 __main__         [I]: Checksum: 33df50258726eb51728abae75ff5be0bb0c5e50775d9aafd077f05b155e88d56
# 19:13:19.158 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.047, Security Aug 2024, Carrier None
# 19:13:19.158 __main__         [D]: Device: caiman
# 19:13:19.158 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 047, Variant None
# 19:13:19.158 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ad1a.240530.047-eb7765ef.zip
# 19:13:19.158 __main__         [I]: Checksum: eb7765ef229d6ae4ec612f0e96afeeeca6947d64468dd73e4e55c21f1ebe6926
# 19:13:19.158 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240905.004, Security Sep 2024, Carrier None
# 19:13:19.158 __main__         [D]: Device: caiman
# 19:13:19.158 __main__         [D]: Build details: Branch AD1A, Date 240905, Number 004, Variant None
# 19:13:19.158 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ad1a.240905.004-36913b8a.zip
# 19:13:19.158 __main__         [I]: Checksum: 36913b8a7de833f691414980835fe971ea6cac54e9bb24f840a0045ac2157e16
# 19:13:19.158 __main__         [I]: Parsed version: Android 15.0.0, Build AP3A.241005.015, Security Oct 2024, Carrier None
# 19:13:19.158 __main__         [D]: Device: caiman
# 19:13:19.158 __main__         [D]: Build details: Branch AP3A, Date 241005, Number 015, Variant None
# 19:13:19.158 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap3a.241005.015-c4aa7b6f.zip
# 19:13:19.158 __main__         [I]: Checksum: c4aa7b6f5547b3f40c0158203789ae913ed5c3fb619e6f8521526a36832b8aa6
# 19:13:19.158 __main__         [I]: Parsed version: Android 15.0.0, Build AP3A.241005.015.A2, Security Oct 2024, Carrier Google Fi
# 19:13:19.158 __main__         [D]: Device: caiman
# 19:13:19.158 __main__         [D]: Build details: Branch AP3A, Date 241005, Number 015, Variant A2
# 19:13:19.158 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap3a.241005.015.a2-9bee7c45.zip
# 19:13:19.158 __main__         [I]: Checksum: 9bee7c45c0dabefb5e6c76385cbdd2c8244117d7c6d4ca4c01cc1f399809658c
# 19:13:19.158 __main__         [I]: Parsed version: Android 15.0.0, Build AP3A.241105.008, Security Nov 2024, Carrier None
# 19:13:19.158 __main__         [D]: Device: caiman
# 19:13:19.158 __main__         [D]: Build details: Branch AP3A, Date 241105, Number 008, Variant None
# 19:13:19.158 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap3a.241105.008-220f2d94.zip
# 19:13:19.158 __main__         [I]: Checksum: 220f2d94900ad387d4b318ac605b72aacdc2b7be11f02dd977378227d55d5297
# 19:13:19.158 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.241205.013, Security Dec 2024, Carrier None
# 19:13:19.158 __main__         [D]: Device: caiman
# 19:13:19.158 __main__         [D]: Build details: Branch AP4A, Date 241205, Number 013, Variant None
# 19:13:19.158 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.241205.013-b914a097.zip
# 19:13:19.158 __main__         [I]: Checksum: b914a097abef5ecc62792fe9cf103b84c676ba64736e7cdc3802102901c87116
# 19:13:19.158 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.241205.013.B1, Security Dec 2024, Carrier Telstra
# 19:13:19.158 __main__         [D]: Device: caiman
# 19:13:19.158 __main__         [D]: Build details: Branch AP4A, Date 241205, Number 013, Variant B1
# 19:13:19.158 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.241205.013.b1-bb072821.zip
# 19:13:19.158 __main__         [I]: Checksum: bb072821e313db1172e1b1079d760923efc2488804b001ba79aa77956b15841e
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.241205.013.C1, Security Dec 2024, Carrier T-Mobile
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch AP4A, Date 241205, Number 013, Variant C1
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.241205.013.c1-b1d00923.zip
# 19:13:19.159 __main__         [I]: Checksum: b1d00923797cbfa5eb219390c1b5b1722cedab0d2f27bc7f220b456e4f237d19
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250105.002, Security Jan 2025, Carrier None
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch AP4A, Date 250105, Number 002, Variant None
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.250105.002-678a8519.zip
# 19:13:19.159 __main__         [I]: Checksum: 678a85190456a7140d34fa2ef10c54c8bd92da2293d6bfca40075649723e4388
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250105.002.B1, Security Jan 2025, Carrier Telstra
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch AP4A, Date 250105, Number 002, Variant B1
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.250105.002.b1-1ca26605.zip
# 19:13:19.159 __main__         [I]: Checksum: 1ca26605909b4bda89cff8d11d0d4269a684edd264ffcce045dc25f5ecd83144
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250105.002.C1, Security Jan 2025, Carrier T-Mobile
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch AP4A, Date 250105, Number 002, Variant C1
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.250105.002.c1-65ce5260.zip
# 19:13:19.159 __main__         [I]: Checksum: 65ce526097190c8f7a13d261b3b908050802bee552e953d21f129df213adf78b
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250205.002, Security Feb 2025, Carrier None
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch AP4A, Date 250205, Number 002, Variant None
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.250205.002-2e8a8511.zip
# 19:13:19.159 __main__         [I]: Checksum: 2e8a851108d2567be61f6252f76c9d1f38a516cea4fe0066d10764eecc803d96
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250205.002.B2, Security Feb 2025, Carrier Telstra
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch AP4A, Date 250205, Number 002, Variant B2
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.250205.002.b2-7eeda60c.zip
# 19:13:19.159 __main__         [I]: Checksum: 7eeda60c44158b885109c86db1e6b3f42a2c29cfde987a34cd405014f8a13de7
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build AP4A.250205.002.C1, Security Feb 2025, Carrier T-Mobile
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch AP4A, Date 250205, Number 002, Variant C1
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-ap4a.250205.002.c1-838a6818.zip
# 19:13:19.159 __main__         [I]: Checksum: 838a6818da8a291dce4472338a7383777b06948ce5300c47cf8ef24079a38d80
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250305.020, Security Mar 2025, Carrier None
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch BP1A, Date 250305, Number 020, Variant None
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250305.020-d387782c.zip
# 19:13:19.159 __main__         [I]: Checksum: d387782c7a8e8d1663cc1f8c4b03b88ff00b6fff0aea9456a8eb66f628e631eb
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250305.020.A2, Security Mar 2025, Carrier EMEA + TW
# 19:13:19.159 __main__         [D]: Device: caiman
# 19:13:19.159 __main__         [D]: Build details: Branch BP1A, Date 250305, Number 020, Variant A2
# 19:13:19.159 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250305.020.a2-44165d9d.zip
# 19:13:19.159 __main__         [I]: Checksum: 44165d9d45658aa910e232e3e6dd45aa6076e8e002fb9715680062bbb67d45e4
# 19:13:19.159 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250405.007, Security Apr 2025, Carrier None
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP1A, Date 250405, Number 007, Variant None
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250405.007-7b8bf880.zip
# 19:13:19.160 __main__         [I]: Checksum: 7b8bf880f0f6a0ab7edb87427728cdd7e1819083b642388bc92dbdf5bff939ec
# 19:13:19.160 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250405.007.A1, Security Apr 2025, Carrier TW, EMEA
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP1A, Date 250405, Number 007, Variant A1
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250405.007.a1-4548eaa3.zip
# 19:13:19.160 __main__         [I]: Checksum: 4548eaa3d11694670d3829be59ee131a8c6a2667dced8bc442aaa6443d114c9c
# 19:13:19.160 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250405.007.C1, Security Apr 2025, Carrier DTAG
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP1A, Date 250405, Number 007, Variant C1
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250405.007.c1-9597c6fa.zip
# 19:13:19.160 __main__         [I]: Checksum: 9597c6faf6f3385ee6fbf2b66223f483817472b0205e91d9a2cbf379d1265149
# 19:13:19.160 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250405.007.D1, Security Apr 2025, Carrier Verizon
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP1A, Date 250405, Number 007, Variant D1
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250405.007.d1-45e3e887.zip
# 19:13:19.160 __main__         [I]: Checksum: 45e3e8872d497d47fe2d0af26b17581203117b0d0433b7a37c7902908e04295a
# 19:13:19.160 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250505.005, Security May 2025, Carrier None
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP1A, Date 250505, Number 005, Variant None
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250505.005-fa38a01c.zip
# 19:13:19.160 __main__         [I]: Checksum: fa38a01c7f3eb8a96b6f9891a5db2b5b7d0492b10087981c0dae4ab3e313b7cd
# 19:13:19.160 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250505.005.A1, Security May 2025, Carrier TW, EMEA
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP1A, Date 250505, Number 005, Variant A1
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250505.005.a1-1511de24.zip
# 19:13:19.160 __main__         [I]: Checksum: 1511de2494832c44e070f2a2e6e2729ca82933eca8652c3899246977a29c36de
# 19:13:19.160 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250505.005.C1, Security May 2025, Carrier DTAG
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP1A, Date 250505, Number 005, Variant C1
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250505.005.c1-812c95d9.zip
# 19:13:19.160 __main__         [I]: Checksum: 812c95d956c314e8ae781999a4c9db110825e18a720d03bfee3c5467357592b2
# 19:13:19.160 __main__         [I]: Parsed version: Android 15.0.0, Build BP1A.250505.005.D1, Security May 2025, Carrier Verizon
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP1A, Date 250505, Number 005, Variant D1
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp1a.250505.005.d1-dffcae8d.zip
# 19:13:19.160 __main__         [I]: Checksum: dffcae8d260d8fc84be4b7491c73c1c11cbef3ffb279e79ed1ea554eb9b90c34
# 19:13:19.160 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250605.031.A2, Security Jun 2025, Carrier None
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP2A, Date 250605, Number 031, Variant A2
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp2a.250605.031.a2-3748a4e1.zip
# 19:13:19.160 __main__         [I]: Checksum: 3748a4e149c9691eec8c0a2cdb16b99c2cc252d967878c9c354ed805ca072a1c
# 19:13:19.160 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250705.008, Security Jul 2025, Carrier None
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP2A, Date 250705, Number 008, Variant None
# 19:13:19.160 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp2a.250705.008-522a7e25.zip
# 19:13:19.160 __main__         [I]: Checksum: 522a7e25df3b894a52cad4cb85d92652050b3bdc817dc4b189e8a18639b60682
# 19:13:19.160 __main__         [I]: Parsed version: Android 16.0.0, Build BP2A.250805.005, Security Aug 2025, Carrier None
# 19:13:19.160 __main__         [D]: Device: caiman
# 19:13:19.160 __main__         [D]: Build details: Branch BP2A, Date 250805, Number 005, Variant None
# 19:13:19.161 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp2a.250805.005-be9ac7bd.zip
# 19:13:19.161 __main__         [I]: Checksum: be9ac7bd67fbc752e121024c38f9828cfbb499dd6f3b7118818b775f9eb5cf64
# 19:13:19.161 __main__         [I]: Parsed version: Android 16.0.0, Build BP3A.250905.014, Security Sep 2025, Carrier None
# 19:13:19.161 __main__         [D]: Device: caiman
# 19:13:19.161 __main__         [D]: Build details: Branch BP3A, Date 250905, Number 014, Variant None
# 19:13:19.161 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/caiman-ota-bp3a.250905.014-8453649c.zip
# 19:13:19.161 __main__         [I]: Checksum: 8453649c19110c9336fbfd3bbab0d2eb6d57c303936803dfdf6d4a4fb0dc9205
# 19:13:19.161 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.030, Security Aug 2024, Carrier None
# 19:13:19.161 __main__         [D]: Device: komodo
# 19:13:19.161 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 030, Variant None
# 19:13:19.161 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/komodo-ota-ad1a.240530.030-d76aa699.zip
# 19:13:19.161 __main__         [I]: Checksum: d76aa69933b62cdc029efffd7c1b51442ba725f4aa6f088870acc529666b0138
# 19:13:19.161 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.030.A1, Security Aug 2024, Carrier India only
# 19:13:19.161 __main__         [D]: Device: komodo
# 19:13:19.161 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 030, Variant A1
# 19:13:19.161 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/komodo-ota-ad1a.240530.030.a1-911531c4.zip
# 19:13:19.161 __main__         [I]: Checksum: 911531c434e916d1cfede4dc358b23bde72cb67f213815b25a87d9a6815e545d
# 19:13:19.162 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.030.A2, Security Aug 2024, Carrier VZW/US Emerging carriers + gStore
# 19:13:19.162 __main__         [D]: Device: komodo
# 19:13:19.162 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 030, Variant A2
# 19:13:19.162 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/komodo-ota-ad1a.240530.030.a2-05bc8513.zip
# 19:13:19.162 __main__         [I]: Checksum: 05bc85139d21ac44a681c89893fc704f9220ceaae78fbcacba3de09836f606ad
# 19:13:19.162 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240530.047, Security Aug 2024, Carrier None
# 19:13:19.162 __main__         [D]: Device: komodo
# 19:13:19.162 __main__         [D]: Build details: Branch AD1A, Date 240530, Number 047, Variant None
# 19:13:19.162 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/komodo-ota-ad1a.240530.047-01e062a6.zip
# 19:13:19.162 __main__         [I]: Checksum: 01e062a698e968e6671aa633fc23b76a01db9861bde054ca37c0d20010db74b5
# 19:13:19.162 __main__         [I]: Parsed version: Android 14.0.0, Build AD1A.240905.004, Security Sep 2024, Carrier None
# 19:13:19.162 __main__         [D]: Device: komodo
# 19:13:19.162 __main__         [D]: Build details: Branch AD1A, Date 240905, Number 004, Variant None
# 19:13:19.162 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/komodo-ota-ad1a.240905.004-323f7f98.zip
# 19:13:19.163 __main__         [I]: Checksum: 323f7f981f90e717260356a2ffa7a5c996a3d913235e6ae3cb121a28f40af010
# 19:13:19.163 __main__         [I]: Parsed version: Android 15.0.0, Build AP3A.241005.015, Security Oct 2024, Carrier None
# 19:13:19.163 __main__         [D]: Device: komodo
# 19:13:19.163 __main__         [D]: Build details: Branch AP3A, Date 241005, Number 015, Variant None
# ...
# 19:13:19.331 __main__         [E]: Error parsing build ID 'M4B30Z' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB29X)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30D)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB30G)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30I)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB30J)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30M)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB30K)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30O)
# 19:13:19.331 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB30R)
# 19:13:19.332 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30W)
# 19:13:19.332 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB30W)
# 19:13:19.332 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB31E)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'MMB30Y' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'MOB31H' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD90Z' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'MMB31C' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'MOB31K' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD91P' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD91U' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'MOB31S' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD91X' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F26Q' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F26R' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD91Y' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD91Z' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'MOB31T' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD92D' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD92E' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F26U' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD92F' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NBD92G' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F26Y' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F27C' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F27E' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F27H' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F27I' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N8I11B' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NGI55D' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N6F27M' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'N8I11F' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [E]: Error parsing build ID 'NGI77B' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.332 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30D)
# 19:13:19.332 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30J)
# 19:13:19.332 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30M)
# 19:13:19.332 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30P)
# 19:13:19.332 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30X)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB29X)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30D)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30J)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB30J)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30M)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB30M)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30P)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB30S)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30X)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MMB29X)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30D)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30G)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30M)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30P)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30W)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB31E)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 7.0.0 (NRD90R)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'NRD91N' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'NMF26F' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F26Q' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F26T' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F26X' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F27B' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F27E' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F27I' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F27K' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F27O' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F27P' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30D)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30G)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30M)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30P)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30W)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 7.0.0 (NRD90M)
# 19:13:19.333 __main__         [W]: Skipping row with unrecognized version format: 7.0.0 (NRD90R)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'NRD91D' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'NRD91N' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'NMF26F' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.333 __main__         [E]: Error parsing build ID 'N4F26M' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N4F26Q' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N4F26T' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N4F26X' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N4F27B' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N9F27C' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N9F27F' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N9F27H' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N9F27L' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N9F27M' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30D)
# 19:13:19.334 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30G)
# 19:13:19.334 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30M)
# 19:13:19.334 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30P)
# 19:13:19.334 __main__         [W]: Skipping row with unrecognized version format: 6.0.1 (MOB30W)
# 19:13:19.334 __main__         [W]: Skipping row with unrecognized version format: 7.0.0 (NRD90M)
# 19:13:19.334 __main__         [W]: Skipping row with unrecognized version format: 7.0.0 (NRD90R)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'NRD91D' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'NRD91N' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'NMF26J' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'NMF26R' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'NMF26X' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'NMF27D' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N2G47H' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N2G47R' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N2G47X' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N2G48B' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [E]: Error parsing build ID 'N2G48C' (most likely due to old version format): not enough values to unpack (expected 3, got 1)
# 19:13:19.334 __main__         [I]: Parsed version: Android 8.0.0, Build OPR6.170623.021, Security Sep 2017, Carrier None
# 19:13:19.334 __main__         [D]: Device: fugu
# 19:13:19.334 __main__         [D]: Build details: Branch OPR6, Date 170623, Number 021, Variant None
# 19:13:19.334 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/fugu-ota-opr6.170623.021-1474ea3b.zip
# 19:13:19.334 __main__         [I]: Checksum: 1474ea3b8b281493c58582581b76d29190abb952656c27c7882f90fcff5957be
# 19:13:19.334 __main__         [I]: Parsed version: Android 8.0.0, Build OPR2.170623.027, Security Nov 2017, Carrier None
# 19:13:19.334 __main__         [D]: Device: fugu
# 19:13:19.334 __main__         [D]: Build details: Branch OPR2, Date 170623, Number 027, Variant None
# 19:13:19.334 __main__         [I]: Found download link: https://dl.google.com/dl/android/aosp/fugu-ota-opr2.170623.027-401d182e.zip
# 19:13:19.334 __main__         [I]: Checksum: 401d182ecee4258bab1f78299ddcd2076413c9672fa4d1f9f8c6eeedb1bfd4aa
# 19:13:19.335 __main__         [I]: Fetched 1439 OTA entries

# %%
import pandas as pd
ota_df = pd.DataFrame(otas)
ota_df['obj'] = otas
filtered_releases = ota_df[ota_df['device'] == 'lynx'] # I only want releases for the pixel 7a
filtered_releases = filtered_releases[filtered_releases['carrier'].isnull()] # I only want releases for the unlocked version
filtered_releases.sort_values(by=['build_date', 'build_number'], ascending=[False, False], inplace=True)
filtered_releases

selected_ota = filtered_releases.iloc[0].obj
download_dir = os.path.join(os.getcwd(), 'downloads')
selected_ota.download(download_dir=download_dir, overwrite=False)
# Out:
# 19:13:20.830 __main__         [W]: File /home/cyphix/repos/pixel-ota/downloads/lynx-ota-BP3A.250905.014.zip already exists, skipping download.
# Verifying checksum:   0%|          | 0.00/2.89G [00:00<?, ?B/s]
# 19:13:22.794 __main__         [I]: Checksum verified for /home/cyphix/repos/pixel-ota/downloads/lynx-ota-BP3A.250905.014.zip
# '/home/cyphix/repos/pixel-ota/downloads/lynx-ota-BP3A.250905.014.zip'
